# %% [markdown]
# # Relatórios de cliques e vendas

# %%
import pandas as pd

path_erp_vendas = "./dados/erp_vendas.csv"
path_relatorio_marketing = "./dados/relatorio_marketing.csv"
df_erp_vendas = pd.read_csv(path_erp_vendas)
df_relatorio_marketing = pd.read_csv(path_relatorio_marketing)

# %%
df_erp_vendas.head(7)
# Out:
#    id_pedido  data_venda                  produto  valor_real  \
# 0       1001  2026-04-10        Cadeira Gamer RGB       899.9
# 1       1002  2026-04-10           Sofá 3 Lugares      1500.0
# 2       1003  2026-04-11        Cadeira Gamer RGB       899.9
# 3       1004  2026-04-12  Mesa de Vidro 6 Lugares      1890.0
# 4       1006  2026-04-14            Estante TV 65       450.0
# 5       1007  2026-04-15        Poltrona do Papai       799.0
#
#   metodo_pagamento status_pagamento
# 0              PIX             Pago
# 1           Boleto        Cancelado
# 2           Cartao             Pago
# 3              PIX             Pago
# 4           Cartao        Estornado
# 5              PIX             Pago

# %%
df_erp_vendas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_pedido         6 non-null      int64
#  1   data_venda        6 non-null      str
#  2   produto           6 non-null      str
#  3   valor_real        6 non-null      float64
#  4   metodo_pagamento  6 non-null      str
#  5   status_pagamento  6 non-null      str
# dtypes: float64(1), int64(1), str(4)
# memory usage: 420.0 bytes

# %%
df_relatorio_marketing.head(7)
# Out:
#   id_transacao        data                  campanha                  produto  \
# 0     TRX-1001  2026-04-10       Cadeira_Gamer_Promo        Cadeira Gamer RGB
# 1     TRX-1002  2026-04-10  Sofa_Retratil_Lancamento           Sofá 3 Lugares
# 2     TRX-1003  2026-04-11       Cadeira_Gamer_Promo        Cadeira Gamer RGB
# 3     TRX-1003  2026-04-11       Cadeira_Gamer_Promo        Cadeira Gamer RGB
# 4     TRX-1004  2026-04-12       Mesa_Jantar_Premium  Mesa de Vidro 6 Lugares
# 5     TRX-1005  2026-04-13  Sofa_Retratil_Lancamento           Sofá 3 Lugares
# 6     TRX-1006  2026-04-14         Estante_Home_Sale            Estante TV 65
#
#    valor_conversao    status
# 0            899.9  Aprovado
# 1           1500.0  Aprovado
# 2            899.9  Aprovado
# 3            899.9  Aprovado
# 4           2100.0  Aprovado
# 5           1500.0  Aprovado
# 6            450.0  Aprovado

# %%
df_relatorio_marketing.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_transacao     7 non-null      str
#  1   data             7 non-null      str
#  2   campanha         7 non-null      str
#  3   produto          7 non-null      str
#  4   valor_conversao  7 non-null      float64
#  5   status           7 non-null      str
# dtypes: float64(1), str(5)
# memory usage: 468.0 bytes

# %% [markdown]
# # Ajuste dType Column "data"

# %%
#df_erp_vendas['data_venda'] = df_erp_vendas['data_venda'].astype('datetime64[ns]')
df_erp_vendas['data_venda'] = pd.to_datetime(df_erp_vendas['data_venda'], errors='coerce')

#df_relatorio_marketing['data'] = df_relatorio_marketing['data'].astype('datetime64[ns]')
df_relatorio_marketing['data'] = pd.to_datetime(df_relatorio_marketing['data'], errors='coerce')

# %%
df_erp_vendas.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id_pedido         6 non-null      int64
#  1   data_venda        6 non-null      datetime64[us]
#  2   produto           6 non-null      str
#  3   valor_real        6 non-null      float64
#  4   metodo_pagamento  6 non-null      str
#  5   status_pagamento  6 non-null      str
# dtypes: datetime64[us](1), float64(1), int64(1), str(3)
# memory usage: 420.0 bytes

# %%
df_relatorio_marketing.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_transacao     7 non-null      str
#  1   data             7 non-null      datetime64[us]
#  2   campanha         7 non-null      str
#  3   produto          7 non-null      str
#  4   valor_conversao  7 non-null      float64
#  5   status           7 non-null      str
# dtypes: datetime64[us](1), float64(1), str(4)
# memory usage: 468.0 bytes

# %% [markdown]
# # Fixing key before merge

# %%
df_relatorio_marketing['id_transacao'] = df_relatorio_marketing['id_transacao'].str.replace('TRX-','').astype('int64')
df_relatorio_marketing.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_transacao     7 non-null      int64
#  1   data             7 non-null      datetime64[us]
#  2   campanha         7 non-null      str
#  3   produto          7 non-null      str
#  4   valor_conversao  7 non-null      float64
#  5   status           7 non-null      str
# dtypes: datetime64[us](1), float64(1), int64(1), str(3)
# memory usage: 468.0 bytes

# %% [markdown]
# # Merging dfs

# %%
df_erp_vendas.head(7)
# Out:
#    id_pedido data_venda                  produto  valor_real metodo_pagamento  \
# 0       1001 2026-04-10        Cadeira Gamer RGB       899.9              PIX
# 1       1002 2026-04-10           Sofá 3 Lugares      1500.0           Boleto
# 2       1003 2026-04-11        Cadeira Gamer RGB       899.9           Cartao
# 3       1004 2026-04-12  Mesa de Vidro 6 Lugares      1890.0              PIX
# 4       1006 2026-04-14            Estante TV 65       450.0           Cartao
# 5       1007 2026-04-15        Poltrona do Papai       799.0              PIX
#
#   status_pagamento
# 0             Pago
# 1        Cancelado
# 2             Pago
# 3             Pago
# 4        Estornado
# 5             Pago

# %%
df_relatorio_marketing.head(7)
# Out:
#    id_transacao       data                  campanha                  produto  \
# 0          1001 2026-04-10       Cadeira_Gamer_Promo        Cadeira Gamer RGB
# 1          1002 2026-04-10  Sofa_Retratil_Lancamento           Sofá 3 Lugares
# 2          1003 2026-04-11       Cadeira_Gamer_Promo        Cadeira Gamer RGB
# 3          1003 2026-04-11       Cadeira_Gamer_Promo        Cadeira Gamer RGB
# 4          1004 2026-04-12       Mesa_Jantar_Premium  Mesa de Vidro 6 Lugares
# 5          1005 2026-04-13  Sofa_Retratil_Lancamento           Sofá 3 Lugares
# 6          1006 2026-04-14         Estante_Home_Sale            Estante TV 65
#
#    valor_conversao    status
# 0            899.9  Aprovado
# 1           1500.0  Aprovado
# 2            899.9  Aprovado
# 3            899.9  Aprovado
# 4           2100.0  Aprovado
# 5           1500.0  Aprovado
# 6            450.0  Aprovado

# %%
#df_erp_vendas['data_venda'] = df_erp_vendas['data_venda'].astype('datetime64[ns]')
df_erp_vendas['data_venda'] = pd.to_datetime(df_erp_vendas['data_venda'], errors='coerce')

#df_relatorio_marketing['data'] = df_relatorio_marketing['data'].astype('datetime64[ns]')
df_relatorio_marketing['data'] = pd.to_datetime(df_relatorio_marketing['data'], errors='coerce')

# %%
df_compare_erp_relatorio = pd.merge(
    df_erp_vendas, 
    df_relatorio_marketing, 
    left_on='id_pedido', 
    right_on='id_transacao', 
    how='outer', 
    suffixes=("_erp", "_mkt")
)
 
df_compare_erp_relatorio
# Out:
#    id_pedido data_venda              produto_erp  valor_real metodo_pagamento  \
# 0     1001.0 2026-04-10        Cadeira Gamer RGB       899.9              PIX
# 1     1002.0 2026-04-10           Sofá 3 Lugares      1500.0           Boleto
# 2     1003.0 2026-04-11        Cadeira Gamer RGB       899.9           Cartao
# 3     1003.0 2026-04-11        Cadeira Gamer RGB       899.9           Cartao
# 4     1004.0 2026-04-12  Mesa de Vidro 6 Lugares      1890.0              PIX
# 5        NaN        NaT                      NaN         NaN              NaN
# 6     1006.0 2026-04-14            Estante TV 65       450.0           Cartao
# 7     1007.0 2026-04-15        Poltrona do Papai       799.0              PIX
#
#   status_pagamento  id_transacao       data                  campanha  \
# 0             Pago        1001.0 2026-04-10       Cadeira_Gamer_Promo
# 1        Cancelado        1002.0 2026-04-10  Sofa_Retratil_Lancamento
# 2             Pago        1003.0 2026-04-11       Cadeira_Gamer_Promo
# 3             Pago        1003.0 2026-04-11       Cadeira_Gamer_Promo
# 4             Pago        1004.0 2026-04-12       Mesa_Jantar_Premium
# 5              NaN        1005.0 2026-04-13  Sofa_Retratil_Lancamento
# 6        Estornado        1006.0 2026-04-14         Estante_Home_Sale
# 7             Pago           NaN        NaT                       NaN
#
#                produto_mkt  valor_conversao    status
# 0        Cadeira Gamer RGB            899.9  Aprovado
# 1           Sofá 3 Lugares           1500.0  Aprovado
# 2        Cadeira Gamer RGB            899.9  Aprovado
# 3        Cadeira Gamer RGB            899.9  Aprovado
# 4  Mesa de Vidro 6 Lugares           2100.0  Aprovado
# 5           Sofá 3 Lugares           1500.0  Aprovado
# 6            Estante TV 65            450.0  Aprovado
# 7                      NaN              NaN       NaN

# %%
df_compare_erp_relatorio.drop(columns='produto_mkt', inplace=True)

# %% [markdown]
# # Checking Empty IDs

# %%
df_id_pedido_nas = df_compare_erp_relatorio[df_compare_erp_relatorio["id_pedido"].isna()]
df_id_pedido_nas
# Out:
#    id_pedido data_venda produto_erp  valor_real metodo_pagamento  \
# 5        NaN        NaT         NaN         NaN              NaN
#
#   status_pagamento  id_transacao       data                  campanha  \
# 5              NaN        1005.0 2026-04-13  Sofa_Retratil_Lancamento
#
#    valor_conversao    status
# 5           1500.0  Aprovado

# %%
df_id_transacao_nas = df_compare_erp_relatorio[df_compare_erp_relatorio["id_transacao"].isna()]
df_id_transacao_nas
# Out:
#    id_pedido data_venda        produto_erp  valor_real metodo_pagamento  \
# 7     1007.0 2026-04-15  Poltrona do Papai       799.0              PIX
#
#   status_pagamento  id_transacao data campanha  valor_conversao status
# 7             Pago           NaN  NaT      NaN              NaN    NaN

# %% [markdown]
# # Checking Payment Issue

# %%
is_status_pagamento_not_Pago = df_compare_erp_relatorio["status_pagamento"] != "Pago"
df_status_pagamento_payment_issue = df_compare_erp_relatorio[is_status_pagamento_not_Pago]
df_status_pagamento_payment_issue
# Out:
#    id_pedido data_venda     produto_erp  valor_real metodo_pagamento  \
# 1     1002.0 2026-04-10  Sofá 3 Lugares      1500.0           Boleto
# 5        NaN        NaT             NaN         NaN              NaN
# 6     1006.0 2026-04-14   Estante TV 65       450.0           Cartao
#
#   status_pagamento  id_transacao       data                  campanha  \
# 1        Cancelado        1002.0 2026-04-10  Sofa_Retratil_Lancamento
# 5              NaN        1005.0 2026-04-13  Sofa_Retratil_Lancamento
# 6        Estornado        1006.0 2026-04-14         Estante_Home_Sale
#
#    valor_conversao    status
# 1           1500.0  Aprovado
# 5           1500.0  Aprovado
# 6            450.0  Aprovado

# %% [markdown]
# # Checking Price Issue

# %%
s_valor_real = df_compare_erp_relatorio["valor_real"]
s_valor_conversao = df_compare_erp_relatorio["valor_conversao"]
df_compare_s_valor_conversao = s_valor_real.compare( s_valor_conversao, result_names=("valor","conversao") )
df_compare_s_valor_conversao
# Out:
#     valor  conversao
# 4  1890.0     2100.0
# 5     NaN     1500.0
# 7   799.0        NaN

# %% [markdown]
# # Shortening price comparison

# %%
mask_price_comparison = s_valor_real != s_valor_conversao

# %%
df_overview_issues = df_compare_erp_relatorio[ 
    (is_status_pagamento_not_Pago) 
    | 
    (s_valor_real != s_valor_conversao) 
]
df_overview_issues
# Out:
#    id_pedido data_venda              produto_erp  valor_real metodo_pagamento  \
# 1     1002.0 2026-04-10           Sofá 3 Lugares      1500.0           Boleto
# 4     1004.0 2026-04-12  Mesa de Vidro 6 Lugares      1890.0              PIX
# 5        NaN        NaT                      NaN         NaN              NaN
# 6     1006.0 2026-04-14            Estante TV 65       450.0           Cartao
# 7     1007.0 2026-04-15        Poltrona do Papai       799.0              PIX
#
#   status_pagamento  id_transacao       data                  campanha  \
# 1        Cancelado        1002.0 2026-04-10  Sofa_Retratil_Lancamento
# 4             Pago        1004.0 2026-04-12       Mesa_Jantar_Premium
# 5              NaN        1005.0 2026-04-13  Sofa_Retratil_Lancamento
# 6        Estornado        1006.0 2026-04-14         Estante_Home_Sale
# 7             Pago           NaN        NaT                       NaN
#
#    valor_conversao    status
# 1           1500.0  Aprovado
# 4           2100.0  Aprovado
# 5           1500.0  Aprovado
# 6            450.0  Aprovado
# 7              NaN       NaN

# %%
df_overview_issues.to_csv("./dados/relatorio_fraudes.csv")
